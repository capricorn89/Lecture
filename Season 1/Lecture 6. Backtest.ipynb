# %%
import os
import pandas as pd
import numpy as np
import datetime

# %%
rebalData = pd.read_excel('rebalData_1906.xlsx') # 전체 리밸런싱 스케줄 불러오기
priceData = pd.read_excel('PE Ratio_190530.xlsx', sheet_name='P')  # 전체 가격 데이터 불러오기

def data_cleansing_quantiwise(rawData):
    '''Quantiwise 제공 시계열데이터 클렌징 용도
    - 열 : 종목명
    - 행 : 시계열
    '''    
    firmCode = rawData.iloc[6, 1:].values
    dateIndex = rawData.iloc[13:, 0].values
    newData = rawData.iloc[13:,1:]
    newData.columns = firmCode
    newData.index = dateIndex
    return newData

priceData = data_cleansing_quantiwise(priceData)

# %%
priceData.head()
# Out:
#            A000010 A000020 A000030 A000040 A000050 A000060 A000070 A000080  \
# 1999-01-29    5823    2640    8700   16333    1413    1076   13933    4500
# 1999-02-26    4570    2219    8200   12737    1298    1076   11557    3360
# 1999-03-31    6140    2521   12000   12287    1406    1525   16526    3830
# 1999-04-30    7000    3116   10300   13186    1867    1819   21926    5700
# 1999-05-31    6260    3399    7750   14685    1961    1664   24410    4750
#
#            A000090 A000100   ...   A300720 A306200 A307950 A316140 A900030  \
# 1999-01-29     NaN   14755   ...       NaN     NaN     NaN     NaN     NaN
# 1999-02-26     NaN   13625   ...       NaN     NaN     NaN     NaN     NaN
# 1999-03-31     NaN   15608   ...       NaN     NaN     NaN     NaN     NaN
# 1999-04-30     NaN   16802   ...       NaN     NaN     NaN     NaN     NaN
# 1999-05-31     NaN   19147   ...       NaN     NaN     NaN     NaN     NaN
#
#            A900050 A900140 A950010 A950070 A950100
# 1999-01-29     NaN     NaN     NaN     NaN     NaN
# 1999-02-26     NaN     NaN     NaN     NaN     NaN
# 1999-03-31     NaN     NaN     NaN     NaN     NaN
# 1999-04-30     NaN     NaN     NaN     NaN     NaN
# 1999-05-31     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 1197 columns]

# %%
rebalData.head()
# Out:
#         date     code    weight
# 0 2001-02-28  A000700  0.033333
# 1 2001-02-28  A001440  0.033333
# 2 2001-02-28  A025830  0.033333
# 3 2001-02-28  A011200  0.033333
# 4 2001-02-28  A003030  0.033333

# %%
rebal_schedule = list(set(rebalData.date))  # 리밸런싱 일자만 추출 (날짜 오름차순으로 정렬)
rebal_schedule.sort()

# %%
rebal_schedule
# Out:
# [Timestamp('2001-02-28 00:00:00'),
#  Timestamp('2001-05-31 00:00:00'),
#  Timestamp('2001-08-31 00:00:00'),
#  Timestamp('2001-11-30 00:00:00'),
#  Timestamp('2002-02-28 00:00:00'),
#  Timestamp('2002-05-31 00:00:00'),
#  Timestamp('2002-08-30 00:00:00'),
#  Timestamp('2002-11-29 00:00:00'),
#  Timestamp('2003-02-28 00:00:00'),
#  Timestamp('2003-05-30 00:00:00'),
#  Timestamp('2003-08-29 00:00:00'),
#  Timestamp('2003-11-28 00:00:00'),
#  Timestamp('2004-02-27 00:00:00'),
#  Timestamp('2004-05-31 00:00:00'),
#  Timestamp('2004-08-31 00:00:00'),
#  Timestamp('2004-11-30 00:00:00'),
#  Timestamp('2005-02-28 00:00:00'),
#  Timestamp('2005-05-31 00:00:00'),
#  Timestamp('2005-08-31 00:00:00'),
#  Timestamp('2005-11-30 00:00:00'),
#  Timestamp('2006-02-28 00:00:00'),
#  Timestamp('2006-05-31 00:00:00'),
#  Timestamp('2006-08-31 00:00:00'),
#  Timestamp('2006-11-30 00:00:00'),
#  Timestamp('2007-02-28 00:00:00'),
#  Timestamp('2007-05-31 00:00:00'),
#  Timestamp('2007-08-31 00:00:00'),
#  Timestamp('2007-11-30 00:00:00'),
#  Timestamp('2008-02-29 00:00:00'),
#  Timestamp('2008-05-30 00:00:00'),
#  Timestamp('2008-08-29 00:00:00'),
#  Timestamp('2008-11-28 00:00:00'),
#  Timestamp('2009-02-27 00:00:00'),
#  Timestamp('2009-05-29 00:00:00'),
#  Timestamp('2009-08-31 00:00:00'),
#  Timestamp('2009-11-30 00:00:00'),
#  Timestamp('2010-02-26 00:00:00'),
#  Timestamp('2010-05-31 00:00:00'),
#  Timestamp('2010-08-31 00:00:00'),
#  Timestamp('2010-11-30 00:00:00'),
#  Timestamp('2011-02-28 00:00:00'),
#  Timestamp('2011-05-31 00:00:00'),
#  Timestamp('2011-08-31 00:00:00'),
#  Timestamp('2011-11-30 00:00:00'),
#  Timestamp('2012-02-29 00:00:00'),
#  Timestamp('2012-05-31 00:00:00'),
#  Timestamp('2012-08-31 00:00:00'),
#  Timestamp('2012-11-30 00:00:00'),
#  Timestamp('2013-02-28 00:00:00'),
#  Timestamp('2013-05-31 00:00:00'),
#  Timestamp('2013-08-30 00:00:00'),
#  Timestamp('2013-11-29 00:00:00'),
#  Timestamp('2014-02-28 00:00:00'),
#  Timestamp('2014-05-30 00:00:00'),
#  Timestamp('2014-08-29 00:00:00'),
#  Timestamp('2014-11-28 00:00:00'),
#  Timestamp('2015-02-27 00:00:00'),
#  Timestamp('2015-05-29 00:00:00'),
#  Timestamp('2015-08-31 00:00:00'),
#  Timestamp('2015-11-30 00:00:00'),
#  Timestamp('2016-02-29 00:00:00'),
#  Timestamp('2016-05-31 00:00:00'),
#  Timestamp('2016-08-31 00:00:00'),
#  Timestamp('2016-11-30 00:00:00'),
#  Timestamp('2017-02-28 00:00:00'),
#  Timestamp('2017-05-31 00:00:00'),
#  Timestamp('2017-08-31 00:00:00'),
#  Timestamp('2017-11-30 00:00:00'),
#  Timestamp('2018-02-28 00:00:00'),
#  Timestamp('2018-05-31 00:00:00'),
#  Timestamp('2018-08-31 00:00:00'),
#  Timestamp('2018-11-30 00:00:00'),
#  Timestamp('2019-02-28 00:00:00'),
#  Timestamp('2019-05-29 00:00:00')]

# %%
# 주가 데이터에서 리밸련싱 날짜에 해당하는 값만 추출
rebal_price = priceData.loc[rebal_schedule,:]
rebal_price.head()
# Out:
#            A000010 A000020 A000030 A000040 A000050 A000060 A000070 A000080  \
# 2001-02-28    2545    1661     865    7792    1889     316   11557    3100
# 2001-05-31    2685    1926     865    9141    1817     558   15553    4000
# 2001-08-31    2220    1500     865    9740    1593     413   14219    3600
# 2001-11-30    3330    1940     865    7792    1608     646   16533    3330
# 2002-02-28    5720    2040     865    4600    1860    1393   27445    3500
#
#            A000090 A000100   ...   A300720 A306200 A307950 A316140 A900030  \
# 2001-02-28     NaN   22286   ...       NaN     NaN     NaN     NaN     NaN
# 2001-05-31     NaN   25596   ...       NaN     NaN     NaN     NaN     NaN
# 2001-08-31     NaN   34036   ...       NaN     NaN     NaN     NaN     NaN
# 2001-11-30     NaN   34146   ...       NaN     NaN     NaN     NaN     NaN
# 2002-02-28     NaN   34856   ...       NaN     NaN     NaN     NaN     NaN
#
#            A900050 A900140 A950010 A950070 A950100
# 2001-02-28     NaN     NaN     NaN     NaN     NaN
# 2001-05-31     NaN     NaN     NaN     NaN     NaN
# 2001-08-31     NaN     NaN     NaN     NaN     NaN
# 2001-11-30     NaN     NaN     NaN     NaN     NaN
# 2002-02-28     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 1197 columns]

# %%
priceData.pct_change(3).head()
# Out:
#              A000010   A000020   A000030   A000040   A000050   A000060  \
# 1999-01-29       NaN       NaN       NaN       NaN       NaN       NaN
# 1999-02-26       NaN       NaN       NaN       NaN       NaN       NaN
# 1999-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 1999-04-30  0.202129  0.180303  0.183908 -0.192677  0.321302  0.690520
# 1999-05-31  0.369803  0.531771 -0.054878  0.152940  0.510786  0.546468
#
#              A000070   A000080  A000090   A000100   ...     A300720  A306200  \
# 1999-01-29       NaN       NaN      NaN       NaN   ...         NaN      NaN
# 1999-02-26       NaN       NaN      NaN       NaN   ...         NaN      NaN
# 1999-03-31       NaN       NaN      NaN       NaN   ...         NaN      NaN
# 1999-04-30  0.573674  0.266667      NaN  0.138733   ...         NaN      NaN
# 1999-05-31  1.112140  0.413690      NaN  0.405284   ...         NaN      NaN
#
#             A307950  A316140  A900030  A900050  A900140  A950010  A950070  \
# 1999-01-29      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1999-02-26      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1999-03-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1999-04-30      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1999-05-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#             A950100
# 1999-01-29      NaN
# 1999-02-26      NaN
# 1999-03-31      NaN
# 1999-04-30      NaN
# 1999-05-31      NaN
#
# [5 rows x 1197 columns]

# %%
# 수익률 데이터로 변환
rebal_return = rebal_price.pct_change()
rebal_return.head()
# Out:
#              A000010   A000020  A000030   A000040   A000050   A000060  \
# 2001-02-28       NaN       NaN      NaN       NaN       NaN       NaN
# 2001-05-31  0.055010  0.159542      0.0  0.173126 -0.038115  0.765823
# 2001-08-31 -0.173184 -0.221184      0.0  0.065529 -0.123280 -0.259857
# 2001-11-30  0.500000  0.293333      0.0 -0.200000  0.009416  0.564165
# 2002-02-28  0.717718  0.051546      0.0 -0.409651  0.156716  1.156347
#
#              A000070   A000080  A000090   A000100   ...     A300720  A306200  \
# 2001-02-28       NaN       NaN      NaN       NaN   ...         NaN      NaN
# 2001-05-31  0.345764  0.290323      NaN  0.148524   ...         NaN      NaN
# 2001-08-31 -0.085771 -0.100000      NaN  0.329739   ...         NaN      NaN
# 2001-11-30  0.162740 -0.075000      NaN  0.003232   ...         NaN      NaN
# 2002-02-28  0.660013  0.051051      NaN  0.020793   ...         NaN      NaN
#
#             A307950  A316140  A900030  A900050  A900140  A950010  A950070  \
# 2001-02-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 
# 2003-11-28  0.030801  0.000000      NaN  0.199542    ...          NaN
# 2004-02-27 -0.077138  0.000000      NaN -0.029585    ...          NaN
# 2004-05-31  0.148244  0.000000      NaN -0.008714    ...          NaN
# 2004-08-31  0.690165  0.000000      NaN  0.398251    ...          NaN
# 2004-11-30  0.083342  0.000000      NaN  0.103477    ...          NaN
# 2005-02-28 -0.062833  0.000000      NaN -0.036816    ...          NaN
# 2005-05-31  0.047883  0.000000      NaN  0.291312    ...          NaN
# 2005-08-31  0.285894  0.000000      NaN  0.508007    ...          NaN
# 2005-11-30  0.094429  0.000000      NaN -0.035749    ...          NaN
# 2006-02-28  0.042670  0.000000      NaN -0.164263    ...          NaN
# 2006-05-31 -0.076519  0.000000      NaN  0.031035    ...          NaN
# 2006-08-31  0.188830  0.000000      NaN  0.204019    ...          NaN
# 2006-11-30 -0.134530  0.000000      NaN -0.126189    ...          NaN
# 2007-02-28  0.310867  0.000000      NaN  0.123326    ...          NaN
# 2007-05-31  0.044287  0.000000      NaN  0.216618    ...          NaN
# 2007-08-31 -0.236658  0.000000      NaN -0.026828    ...          NaN
# 2007-11-30 -0.125992  0.000000      NaN -0.015731    ...          NaN
# 2008-02-29  0.066673  0.000000      NaN  0.071998    ...          NaN
# 2008-05-30 -0.171873  0.000000      NaN  0.114431    ...          NaN
# ...              ...       ...      ...       ...    ...          ...
# 2012-02-29 -0.284741 -0.180000      NaN -0.033471    ...          NaN
# 2012-05-31  0.076190  0.087805      NaN  0.160177    ...          NaN
# 2012-08-31  0.302655  0.354260      NaN  0.264918    ...          NaN
# 2012-11-30 -0.057065  0.129139      NaN  0.053099    ...          NaN
# 2013-02-28  0.268012 -0.067449      NaN  0.039215    ...          NaN
# 2013-05-31 -0.032955 -0.209119      NaN  0.056603    ...          NaN
# 2013-08-30  0.016451  0.007952      NaN -0.040814    ...          NaN
# 2013-11-29 -0.152601 -0.072978      NaN  0.050533    ...          NaN
# 2014-02-28 -0.012278 -0.080851      NaN -0.106327    ...          NaN
# 2014-05-30  0.154696  0.069444      NaN -0.019836    ...          NaN
# 2014-08-29  0.062201  0.093074      NaN  0.005785    ...          NaN
# 2014-11-28  0.018018 -0.095050      NaN -0.017242    ...          NaN
# 2015-02-27  0.194690 -0.063457      NaN  0.561402    ...          NaN
# 2015-05-29  0.657407  0.032710      NaN -0.069290    ...          NaN
# 2015-08-31 -0.111732  0.092760      NaN  0.114690    ...          NaN
# 2015-11-30  0.113208  0.219462      NaN -0.066789    ...          NaN
# 2016-02-29 -0.169492 -0.147708      NaN  0.226307    ...          NaN
# 2016-05-31 -0.183673 -0.127490      NaN -0.089907    ...          NaN
# 2016-08-31  0.020833 -0.006849      NaN -0.317155    ...          NaN
# 2016-11-30 -0.081633 -0.029885      NaN  0.187093    ...          NaN
# 2017-02-28  0.186667  0.146919      NaN  0.116072    ...          NaN
# 2017-05-31 -0.198502  0.078512      NaN -0.096000    ...          NaN
# 2017-08-31 -0.042056 -0.091954      NaN -0.026550    ...          NaN
# 2017-11-30  0.087805 -0.071730      NaN -0.013345    ...          NaN
# 2018-02-28  0.026906 -0.084091      NaN  0.144234    ...          NaN
# 2018-05-31 -0.109170 -0.166253      NaN  0.004202    ...          NaN
# 2018-08-31 -0.142157  0.041667      NaN -0.048119    ...    -0.128713
# 2018-11-30 -0.036571  0.011429      NaN  0.196612    ...     0.083333
# 2019-02-28 -0.119810  0.135593      NaN -0.072937    ...    -0.083916
# 2019-05-29       NaN       NaN      NaN       NaN    ...          NaN
#
#              A306200  A307950   A316140   A900030   A900050   A900140  \
# 2001-02-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2001-05-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2001-08-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2001-11-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2002-02-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2002-05-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2002-08-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2002-11-29       NaN      NaN       NaN       NaN       NaN       NaN
# 2003-02-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2003-05-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2003-08-29       NaN      NaN       NaN       NaN       NaN       NaN
# 2003-11-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2004-02-27       NaN      NaN       NaN       NaN       NaN       NaN
# 2004-05-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2004-08-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2004-11-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2005-02-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2005-05-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2005-08-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2005-11-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2006-02-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2006-05-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2006-08-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2006-11-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2007-02-28       NaN      NaN       NaN       NaN       NaN       NaN
# 2007-05-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2007-08-31       NaN      NaN       NaN       NaN       NaN       NaN
# 2007-11-30       NaN      NaN       NaN       NaN       NaN       NaN
# 2008-02-29       NaN      NaN       NaN       NaN       NaN       NaN
# 2008-05-30       NaN      NaN       NaN       NaN       NaN       NaN
# ...              ...      ...       ...       ...       ...       ...
# 2012-02-29       NaN      NaN       NaN -0.200627 -0.247942  0.238802
# 2012-05-31       NaN      NaN       NaN  0.000000  0.067031  0.257088
# 2012-08-31       NaN      NaN       NaN  0.000000 -0.206410  0.255525
# 2012-11-30       NaN      NaN       NaN  0.000000  0.192246  0.133229
# 2013-02-28       NaN      NaN       NaN  0.000000 -0.042005  0.508246
# 2013-05-31       NaN      NaN       NaN  0.000000 -0.137199 -0.057738
# 2013-08-30       NaN      NaN       NaN  0.000000  0.408197 -0.019839
# 2013-11-29       NaN      NaN       NaN  0.000000 -0.136205 -0.087264
# 2014-02-28       NaN      NaN       NaN  0.000000 -0.331536 -0.009791
# 2014-05-30       NaN      NaN       NaN  0.000000 -0.512097 -0.245542
# 2014-08-29       NaN      NaN       NaN  0.000000  2.764463 -0.078745
# 2014-11-28       NaN      NaN       NaN  0.000000  0.045005  0.062679
# 2015-02-27       NaN      NaN       NaN  0.000000 -0.213235  0.155492
# 2015-05-29       NaN      NaN       NaN  0.000000 -0.014686 -0.167046
# 2015-08-31       NaN      NaN       NaN  0.000000  0.326558 -0.317582
# 2015-11-30       NaN      NaN       NaN  0.000000 -0.359551 -0.065238
# 2016-02-29       NaN      NaN       NaN  0.000000 -0.347687 -0.215710
# 2016-05-31       NaN      NaN       NaN  0.000000 -0.249389  0.094571
# 2016-08-31       NaN      NaN       NaN  0.000000 -0.055375 -0.216650
# 2016-11-30       NaN      NaN       NaN  0.000000 -0.300000 -0.006512
# 2017-02-28       NaN      NaN       NaN  0.000000 -0.014778 -0.109763
# 2017-05-31       NaN      NaN       NaN  0.000000  0.000000 -0.174839
# 2017-08-31       NaN      NaN       NaN  0.000000  0.000000 -0.176951
# 2017-11-30       NaN      NaN       NaN  0.000000  0.000000  0.011765
# 2018-02-28       NaN      NaN       NaN  0.000000  0.000000 -0.017100
# 2018-05-31       NaN      NaN       NaN  0.000000  0.000000 -0.138019
# 2018-08-31       NaN      NaN       NaN  0.000000  0.000000 -0.373251
# 2018-11-30  0.028708      NaN       NaN  0.000000  0.000000  0.210820
# 2019-02-28  0.026357      NaN -0.054054  0.000000  0.000000 -0.202128
# 2019-05-29       NaN      NaN       NaN       NaN       NaN       NaN
#
#              A950010  A950070   A950100
# 2001-02-28       NaN      NaN       NaN
# 2001-05-31       NaN      NaN       NaN
# 2001-08-31       NaN      NaN       NaN
# 2001-11-30       NaN      NaN       NaN
# 2002-02-28       NaN      NaN       NaN
# 2002-05-31       NaN      NaN       NaN
# 2002-08-30       NaN      NaN       NaN
# 2002-11-29       NaN      NaN       NaN
# 2003-02-28       NaN      NaN       NaN
# 2003-05-30       NaN      NaN       NaN
# 2003-08-29       NaN      NaN       NaN
# 2003-11-28       NaN      NaN       NaN
# 2004-02-27       NaN      NaN       NaN
# 2004-05-31       NaN      NaN       NaN
# 2004-08-31       NaN      NaN       NaN
# 2004-11-30       NaN      NaN       NaN
# 2005-02-28       NaN      NaN       NaN
# 2005-05-31       NaN      NaN       NaN
# 2005-08-31       NaN      NaN       NaN
# 2005-11-30       NaN      NaN       NaN
# 2006-02-28       NaN      NaN       NaN
# 2006-05-31       NaN      NaN       NaN
# 2006-08-31       NaN      NaN       NaN
# 2006-11-30       NaN      NaN       NaN
# 2007-02-28       NaN      NaN       NaN
# 2007-05-31       NaN      NaN       NaN
# 2007-08-31       NaN      NaN       NaN
# 2007-11-30 -0.455275      NaN       NaN
# 2008-02-29 -0.086814      NaN       NaN
# 2008-05-30 -0.260090      NaN       NaN
# ...              ...      ...       ...
# 2012-02-29 -0.279330      0.0       NaN
# 2012-05-31  0.162791      0.0  0.268248
# 2012-08-31  0.056667      0.0  0.391367
# 2012-11-30 -0.047319      0.0  0.065150
# 2013-02-28 -0.036424      0.0  0.330097
# 2013-05-31 -0.061856      0.0  0.127737
# 2013-08-30  0.043956      0.0 -0.190939
# 2013-11-29 -0.077193      0.0  0.016000
# 2014-02-28 -0.398479      0.0  0.059055
# 2014-05-30  0.308470      0.0  0.338290
# 2014-08-29 -0.333333      0.0 -0.005556
# 2014-11-28  0.000000      0.0  0.000000
# 2015-02-27  0.000000      0.0  0.000000
# 2015-05-29  0.000000      0.0  0.000000
# 2015-08-31  0.000000      0.0  0.000000
# 2015-11-30  0.000000      0.0  0.000000
# 2016-02-29  0.000000      0.0  0.000000
# 2016-05-31  0.000000      0.0  0.000000
# 2016-08-31  0.000000      0.0  0.000000
# 2016-11-30  0.000000      0.0  0.000000
# 2017-02-28  0.000000      0.0  0.000000
# 2017-05-31  0.000000      0.0  0.000000
# 2017-08-31  0.000000      0.0  0.000000
# 2017-11-30  0.000000      0.0  0.000000
# 2018-02-28  0.000000      0.0  0.000000
# 2018-05-31  0.000000      0.0  0.000000
# 2018-08-31  0.000000      0.0  0.000000
# 2018-11-30  0.000000      0.0  0.000000
# 2019-02-28  0.000000      0.0  0.000000
# 2019-05-29       NaN      NaN       NaN
#
# [74 rows x 1197 columns]

# %%
rebal_return = rebal_return.shift(-1)  # 5월말 기준 수익률은 2월말 기준 종목데이터와 매칭시켜야 하기 때문에 한줄씩 앞으로 당겨줌

# %%
rebal_return.head()
# Out:
#              A000010   A000020  A000030   A000040   A000050   A000060  \
# 2001-02-28  0.055010  0.159542      0.0  0.173126 -0.038115  0.765823
# 2001-05-31 -0.173184 -0.221184      0.0  0.065529 -0.123280 -0.259857
# 2001-08-31  0.500000  0.293333      0.0 -0.200000  0.009416  0.564165
# 2001-11-30  0.717718  0.051546      0.0 -0.409651  0.156716  1.156347
# 2002-02-28  0.066434 -0.219608      0.0  0.024565  0.052151 -0.150036
#
#              A000070   A000080  A000090   A000100   ...     A300720  A306200  \
# 2001-02-28  0.345764  0.290323      NaN  0.148524   ...         NaN      NaN
# 2001-05-31 -0.085771 -0.100000      NaN  0.329739   ...         NaN      NaN
# 2001-08-31  0.162740 -0.075000      NaN  0.003232   ...         NaN      NaN
# 2001-11-30  0.660013  0.051051      NaN  0.020793   ...         NaN      NaN
# 2002-02-28 -0.255019  0.114286      NaN -0.029866   ...         NaN      NaN
#
#             A307950  A316140  A900030  A900050  A900140  A950010  A950070  \
# 2001-02-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2001-05-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2001-08-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2001-11-30      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2002-02-28      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#             A950100
# 2001-02-28      NaN
# 2001-05-31      NaN
# 2001-08-31      NaN
# 2001-11-30      NaN
# 2002-02-28      NaN
#
# [5 rows x 1197 columns]

# %%
return_quarterly = []

for i in range(len(rebal_schedule)):
    
    rebal_date = rebal_schedule[i]  # 리밸런싱 일자 순차적으로 호출
    firms = rebalData[rebalData['date'] == rebal_date]['code'].values  # 해당 리밸런싱 일자에만 해당하는 종목코드 불러오기
    basket = rebal_return.loc[rebal_date, firms]  # 해당 리밸런싱 일자의 수익률 데이터중 뽑힌 종목코드 데이터만 불러오기
    basket_return = basket.mean()  # 수익률의 평균 계산 (equal-weighted)
    return_quarterly.append(basket_return) # 수익률 리스트에 append

# %%
return_quarterly[:10]
# Out:
# [0.18717243700399286,
#  -0.10084219894275433,
#  0.23240437432049488,
#  0.4409530029759144,
#  -0.07174698414614276,
#  -0.015991177156476907,
#  -0.016034105500320427,
#  -0.16746224264934606,
#  0.2535642995672598,
#  0.26862292616507044]

# %%
# 리밸런싱 일자를 인덱스로 하는 데이터프레임으로 변환 
return_quarterly = pd.DataFrame(return_quarterly, index = rebal_schedule, columns=['return'])

# %%
return_quarterly = return_quarterly.shift(1)  # 수익률의 실현은 그 다음 리밸런싱 일자이기 때문에 한칸씩 뒤로 미뤄줌

# %%
return_quarterly.head()
# Out:
#               return
# 2001-02-28       NaN
# 2001-05-31  0.187172
# 2001-08-31 -0.100842
# 2001-11-30  0.232404
# 2002-02-28  0.440953

# %%
cumreturn_quarterly = (return_quarterly.fillna(0) + 1).cumprod()  # 누적수익률 계산을 위해 1씩 더하고 누적해서 곱함
cumreturn_quarterly.head()
# Out:
#               return
# 2001-02-28  1.000000
# 2001-05-31  1.187172
# 2001-08-31  1.067455
# 2001-11-30  1.315537
# 2002-02-28  1.895626

# %%
# %matplotlib inline
cumreturn_quarterly.plot() # 차트 그리기

# %%
k200_p = pd.read_excel('PE Ratio_190530.xlsx', sheet_name='K200_price')
k200_p = data_cleansing_quantiwise(k200_p)

# %%
k200_p.head()
# Out:
#            IKS200  NaN  NaN
# 1999-01-29  65.72  NaN  NaN
# 1999-02-26  60.28  NaN  NaN
# 1999-03-31  71.84  NaN  NaN
# 1999-04-30  87.15  NaN  NaN
# 1999-05-31  85.68  NaN  NaN

# %%
k200_p = k200_p.iloc[:,0]

# %%
k200_p.head()
# Out:
# 1999-01-29    65.72
# 1999-02-26    60.28
# 1999-03-31    71.84
# 1999-04-30    87.15
# 1999-05-31    85.68
# Name: IKS200, dtype: object

# %%
k200_p = k200_p.loc[rebal_schedule,]
# Out:
# /Users/Woojin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.

# %%
cumreturn_k200 = (k200_p.pct_change().fillna(0)+1).cumprod()

# %%
cumreturn_k200
# Out:
# 2001-02-28    1.000000
# 2001-05-31    1.054755
# 2001-08-31    0.934572
# 2001-11-30    1.109371
# 2002-02-28    1.422512
# 2002-05-31    1.397283
# 2002-08-30    1.282922
# 2002-11-29    1.275991
# 2003-02-28    1.009842
# 2003-05-30    1.116302
# 2003-08-29    1.352786
# 2003-11-28    1.436235
# 2004-02-27    1.606876
# 2004-05-31    1.443582
# 2004-08-31    1.426255
# 2004-11-30    1.571943
# 2005-02-28    1.813834
# 2005-05-31    1.730524
# 2005-08-31    1.941918
# 2005-11-30    2.300388
# 2006-02-28    2.459800
# 2006-05-31    2.370530
# 2006-08-31    2.431938
# 2006-11-30    2.563904
# 2007-02-28    2.539507
# 2007-05-31    3.000416
# 2007-08-31    3.303022
# 2007-11-30    3.353341
# 2008-02-29    3.005961
# 2008-05-30    3.291655
#                 ...
# 2012-02-29    3.702939
# 2012-05-31    3.383005
# 2012-08-31    3.473246
# 2012-11-30    3.524397
# 2013-02-28    3.715137
# 2013-05-31    3.624480
# 2013-08-30    3.489604
# 2013-11-29    3.736762
# 2014-02-28    3.582063
# 2014-05-30    3.603271
# 2014-08-29    3.679096
# 2014-11-28    3.516773
