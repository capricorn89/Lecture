# %%
import numpy as np
import pandas as pd
import calendar

# Load PE ratio Data and K200 Data
raw_per = pd.read_excel('PE Ratio_190530.xlsx', sheet_name = 'PE')
in_k200 = pd.read_excel('PE Ratio_190530.xlsx', sheet_name = 'K200')

# %%
raw_per.head()
# Out:
#             Refresh      Last Update : 2019-05-30 14:38:23 Unnamed: 2  \
# 0                      0                               NaN        NaN
# 1  Time Series (Company)                               NaN        NaN
# 2              Frequency                                 M  Ascending
# 3           Period(From)                          19990101     Korean
# 4             Period(To)                    CPD [20190530]        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2          1        NaN        NaN        NaN        NaN        NaN
# 3          0        NaN        NaN        NaN        NaN        NaN
# 4          0        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9      ...      Unnamed: 1188 Unnamed: 1189 Unnamed: 1190  \
# 0        NaN      ...                NaN           NaN           NaN
# 1        NaN      ...                NaN           NaN           NaN
# 2        NaN      ...                NaN           NaN           NaN
# 3        NaN      ...                NaN           NaN           NaN
# 4        NaN      ...                NaN           NaN           NaN
#
#   Unnamed: 1191 Unnamed: 1192 Unnamed: 1193 Unnamed: 1194 Unnamed: 1195  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   Unnamed: 1196 Unnamed: 1197
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#
# [5 rows x 1198 columns]

# %%
in_k200.head()
# Out:
#             Refresh      Last Update : 2019-05-30 14:39:36 Unnamed: 2  \
# 0                      0                               NaN        NaN
# 1  Time Series (Company)                               NaN        NaN
# 2              Frequency                                 M  Ascending
# 3           Period(From)                          19990101     Korean
# 4             Period(To)                    CPD [20190530]        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2          1        NaN        NaN        NaN        NaN        NaN
# 3          0        NaN        NaN        NaN        NaN        NaN
# 4          0        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9      ...      Unnamed: 1188 Unnamed: 1189 Unnamed: 1190  \
# 0        NaN      ...                NaN           NaN           NaN
# 1        NaN      ...                NaN           NaN           NaN
# 2        NaN      ...                NaN           NaN           NaN
# 3        NaN      ...                NaN           NaN           NaN
# 4        NaN      ...                NaN           NaN           NaN
#
#   Unnamed: 1191 Unnamed: 1192 Unnamed: 1193 Unnamed: 1194 Unnamed: 1195  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   Unnamed: 1196 Unnamed: 1197
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#
# [5 rows x 1198 columns]

# %%
def data_cleansing_ts(rawData):
    '''Quantiwise 제공 시계열데이터 클렌징 용도
    - 열 : 종목명
    - 행 : 시계열
    '''    
    firmCode = rawData.iloc[6, 1:].values
    dateIndex = rawData.iloc[13:, 0].values
    newData = rawData.iloc[13:,1:]
    newData.columns = firmCode
    newData.index = dateIndex
    return newData

data_cleansing_ts(raw_per).head()
# Out:
#            A000010 A000020 A000030 A000040 A000050 A000060 A000070 A000080  \
# 1999-01-29     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1999-02-26     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1999-03-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1999-04-30     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1999-05-31     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#            A000090 A000100   ...   A300720 A306200 A307950 A316140 A900030  \
# 1999-01-29     NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 1999-02-26     NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 1999-03-31     NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 1999-04-30     NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
# 1999-05-31     NaN     NaN   ...       NaN     NaN     NaN     NaN     NaN
#
#            A900050 A900140 A950010 A950070 A950100
# 1999-01-29     NaN     NaN     NaN     NaN     NaN
# 1999-02-26     NaN     NaN     NaN     NaN     NaN
# 1999-03-31     NaN     NaN     NaN     NaN     NaN
# 1999-04-30     NaN     NaN     NaN     NaN     NaN
# 1999-05-31     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 1197 columns]

# %%
# iloc 

## 1) code를 다 불러오기
#rawdata_per.iloc[6,1:]
#codeName = rawdata_per.iloc[6,1:].values  # 값만 불러오고 싶을때
#
#
## 2) 날짜 다 불러오기
#dateList = rawdata_per.iloc[13:,0].values
#
## 3) 값들을 다 불러오기
#allValues = rawdata_per.iloc[13:,1:].values
#
#
## 4) dataframe 형식으로 새로 만들어주기
#'''
#열 : 코드
#행 : 날짜
#그 안에 값들..
#'''
#new_per_data = pd.DataFrame(allValues, columns=codeName, index = dateList)

def data_cleansing_quantiwise(rawData):
    '''Quantiwise 제공 시계열데이터 클렌징 용도
    - 열 : 종목명
    - 행 : 시계열
    '''    
    firmCode = rawData.iloc[6, 1:].values
    dateIndex = rawData.iloc[13:, 0].values
    newData = rawData.iloc[13:,1:]
    newData.columns = firmCode
    newData.index = dateIndex
    return newData

new_per_data = data_cleansing_quantiwise(rawdata_per)

# 모든 열의 이름 (종목코드) 확인
new_per_data.columns

# 첫번째 날 확인
month_1 = new_per_data.index[24]

# loc
# 해당 월의 PER 데이터 추출하기
new_per_data.loc[month_1, :]
per_1 = new_per_data.loc[month_1, :].dropna()

# 그 중에서 하위 30 종목
per_1.astype(float)  # data type을 실수(float)로 바꾸기
per_1.astype(float).nsmallest(30)  # 작은거 30개
per_1.astype(float).nsmallest(30).index  # 작은거 30개의 종목ㅁ코드
